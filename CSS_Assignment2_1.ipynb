# %% [markdown]
# 5. Create a simple blog website about Google fonts. The webpage must have the heading with “Oswald” font align center to the page, below the heading have an image of Google fonts and a paragraph about Google fonts in font “Montserrat” paragraph font style should be“montserrat” font
#
#       - <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Question5</title>
#     <!-- <link rel="stylesheet" href="style5.css"> -->
#     <style>
#       body{
#       margin: 0;
#       padding: 0;
#       font-family: 'Montserrat',sans-serif;
#       background-color: #f9f9f9;
#       color: #333;
#       }
#       .container{
#           max-width: 800px;
#           margin:  auto;
#           padding: 20px;
#           text-align: center;
#       }
#       h1{
#           font-family: 'Oswald',sans-serif;
#           font-size: 48px;
#           margin-bottom: 20px;
#       }
#       img{
#           width: 100%;
#           max-width: 400px;
#           height: auto;
#
#       }
#       p{
#           font-size: 18px;
#           line-height: 1.6;
#           text-align: justify;
#       }
#
#     </style>
# </head>
# <body>
#     <div class="container">
#         <h1 >Oswald Font</h1>
#
#         <img src="download.png" alt="img">
#         <p>
#             Google Fonts is a free and open-source library of web fonts hosted by Google.
#             It allows designers and developers to use high-quality typography in their projects without needing to host font files themselves.
#             With hundreds of font families available, Google Fonts makes it easy to enhance the visual appeal and readability of websites across all devices.
#         </p>
#     </div>
# </body>
# </html>

# %% [markdown]
# 6. Create a simple website as mentioned in the below image. You can get the assets by visiting https://pwskills.com/about-us.
#       - <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Question6</title>
#     <!-- <link rel="stylesheet" href="style6.css"> -->
#     <style>
#       .container{
#       min-width: 800px;
#       height: auto;
#       padding: 20px;
#       border: 4px solid black;
#         }
#       h1{
#           text-align: center;
#           margin-bottom: 20px;
#       }
#       p{
#           padding: 30px;
#           margin-bottom: 20px;
#       }
#       img{
#           width: 100%;
#           height: auto;
#       }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <h1>About Us</h1>
#         <p>
#             PW Skills' mission is to permeate through every student/professional's outlook towards jobs and
#             change their attitude and perspective from "How Can I Do It?" to "Of Course I Can Do It".
#             We aim to do this by providing exceptional up skilling courses at affordable rates,
#             while being tech-forward so anyone, anywhere can access and improve their ability to be successful in life.
#         </p>
#         <img src="aboutUs.png" alt="img">
#     </div>
# </body>
# </html>

# %% [markdown]
# 7. Create a simple webpage with a card similar to question number 2. The card must be semi-transparent as default and on hovering the card must be displayed clearly. Use CSS opacity to achieve this output.
#       -
#       <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Question7</title>
#     <!-- <link rel="stylesheet" href="style7.css"> -->
#     <style>
#       body{
#       margin: 0;
#       padding: 0;
#       }
#       .container{
#           max-width: 800px;
#           height:auto ;
#           background-color: aqua;
#           margin: auto;
#           border-radius: 15px;
#           padding: 20px;
#
#       }
#       img{
#           max-width: 100%;
#       }
#       .container:hover{
#           background-color: rgb(0, 255, 255,0.2);
#       }
#
#     </style>
# </head>
# <body>
#     <div class="container">
#         <img src="pexels-chevanon-1108099.jpg" alt="img">
#         <p>&nbsp;<b>Course Name :</b>Animal Behavior and welfare</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# 8.  Create a simple list of items as mentioned in the below image.
#       - <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Question8</title>
#     <!-- <link rel="stylesheet" href="style8.css"> -->
#     <style>
#
#       .container{
#           width: 800px;
#           border: 2px solid black;
#           padding: 10px;
#       }
#       .list__items{
#           list-style: lower-roman;
#       }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <h1>Requirements</h1>
#         <ol class="list">
#             <li class="list__items">System with minimum i3 processor or better</li>
#             <li class="list__items">At least 4GB of RAM</li>
#             <li class="list__items">Working internet connection</li>
#             <li class="list__items">Dedication to learn</li>
#         </ol>
#     </div>
# </body>
# </html>
